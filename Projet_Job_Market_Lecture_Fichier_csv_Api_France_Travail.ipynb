# %%
# Importer les modules nécessaires
import pandas as pd
from IPython.display import display

# Monter Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Chemin vers le fichier CSV
csv_file_path = 'cleaned_offres_emploi.csv'

# Lire le fichier CSV
df = pd.read_csv(csv_file_path)

# Afficher le nombre de lignes du fichier
num_rows = len(df)
print(f"Nombre de lignes dans le fichier: {num_rows}")

# Afficher le nombre de doublons du fichier
num_doublons = df.duplicated().sum()
print("\nNombre de doublons :", num_doublons)
print(f"Nombre de lignes dans le fichier sans doublons: {num_rows - num_doublons} ")

# Afficher le nombre de valeurs manquantes dans chaque colonne
missing_values = df.isna().sum()
print("le nombre de valeurs manquantes dans chaque colonne")
print(missing_values)


# # Identifier et afficher les lignes dupliquées
# doublons = df[df.duplicated(keep=False)]
# # print("\nLignes en doubles :")
# # display(doublons)

# Afficher les 5 premières lignes du fichier
display(df.head())
# Out:
# Nombre de lignes dans le fichier: 19334
#
# Nombre de doublons : 0
# Nombre de lignes dans le fichier sans doublons: 19334
# le nombre de valeurs manquantes dans chaque colonne
# Title          0
# Company        0
# Description    0
# Date           0
# Address        0
# Salary         0
# Link           0
# dtype: int64
#                                                Title  \
# 0                        Poseur PHOTOVOLTAIQUE (H/F)
# 1  Dessinateur structure métallique / charpente m...
# 2    Ingénieur calcul fondations / gros-oeuvre (H/F)
# 3    Ingénieur calcul fondations / gros-oeuvre (H/F)
# 4  Chargé(e) d'études et de projet VRD - Aménagem...
#
#                        Company  \
# 0                       RPELEC
# 1  APPROACH PEOPLE RECRUITMENT
# 2  APPROACH PEOPLE RECRUITMENT
# 3  APPROACH PEOPLE RECRUITMENT
# 4  APPROACH PEOPLE RECRUITMENT
#
#                                          Description        Date  \
# ...
